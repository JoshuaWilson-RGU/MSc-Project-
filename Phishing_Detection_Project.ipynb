# %% [markdown]
# <a href="https://colab.research.google.com/github/JoshuaWilson-RGU/MSc-Project-/blob/main/Phishing_Detection_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyarrow --upgrade -q
# !pip install transformers torch datasets scikit-learn accelerate -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 13.3 MB/s eta 0:00:00

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from datasets import Dataset
from transformers import (AutoTokenizer,
                          AutoModelForSequenceClassification,
                          TrainingArguments,
                          Trainer,
                          pipeline)

print('All libraries imported.')
# Out:
# All libraries imported.

# %%
CSV_FILENAME   = 'enron.csv'
SUBJECT_COLUMN = 'subject'
BODY_COLUMN    = 'body'
LABEL_COLUMN   = 'label'

SAMPLE_SIZE    = 5000
MODEL_NAME     = 'roberta-base'
EPOCHS         = 5                # training passes (https://arxiv.org/pdf/2507.07101)
BATCH_SIZE     = 8                # same paper suggests 1-8 (https://arxiv.org/pdf/2507.07101)


print('Configuration set.')
# Out:
# Configuration set.
